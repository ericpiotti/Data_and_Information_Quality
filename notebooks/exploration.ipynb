# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
ESERCIZI = pd.read_csv('../Dataset/Comune-di-Milano-Pubblici-esercizi(in)-2.csv',sep=';',encoding='utf-8')
ESERCIZI
# Out:
#          þÿTipo esercizio storico pe              Insegna  \
# 0                                NaN                  NaN
# 1                                NaN                  NaN
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
# ...                              ...                  ...
# 6899  wine,birr.,pub enot.,caff.,the           bar cherry
# 6900  wine,birr.,pub enot.,caff.,the            la balusa
# 6901  wine,birr.,pub enot.,caff.,the  la champagnerie sas
# 6902  wine,birr.,pub enot.,caff.,the          old rooster
# 6903  wine,birr.,pub enot.,caff.,the            starhotel
#
#                                              Ubicazione Tipo via  \
# 0     ALZ NAVIGLIO GRANDE N. 12 ; isolato:057; (z.d. 6)      ALZ
# 1                    ALZ NAVIGLIO GRANDE N. 44 (z.d. 6)      ALZ
# 2                    ALZ NAVIGLIO GRANDE N. 48 (z.d. 6)      ALZ
# 3                     ALZ NAVIGLIO GRANDE N. 8 (z.d. 6)      ALZ
# 4                    ALZ NAVIGLIO PAVESE N. 24 (z.d. 6)      ALZ
# ...                                                 ...      ...
# 6899  VLE DORIA ANDREA N. 12 ; isolato:031; accesso:...      VLE
# 6900  VIA GARIGLIANO N. 5 ; isolato:277; accesso: ac...      VIA
# 6901  VIA SOTTOCORNO PASQUALE N. 4 ; isolato:014; ac...      VIA
# 6902  VIA CASTROVILLARI N. 23 ; isolato:150; accesso...      VIA
# 6903        PZA FONTANA N. 3 ;pza fontana 003; (z.d. 1)      PZA
#
#           Descrizione via Civico  Codice via  ZD        Forma commercio  \
# 0         NAVIGLIO GRANDE     12        5144   6                    NaN
# 1         NAVIGLIO GRANDE     44        5144   6                    NaN
# 2         NAVIGLIO GRANDE     48        5144   6                    NaN
# 3         NAVIGLIO GRANDE      8        5144   6                    NaN
# 4         NAVIGLIO PAVESE     24        5161   6                    NaN
# ...                   ...    ...         ...  ..                    ...
# 6899         DORIA ANDREA     12        2230   2  solo somministrazione
# 6900           GARIGLIANO      5        1134   9  solo somministrazione
# 6901  SOTTOCORNO PASQUALE      4        3152   4  solo somministrazione
# 6902        CASTROVILLARI     23        6299   7  solo somministrazione
# 6903              FONTANA      3         308   1  solo somministrazione
#
#      Forma commercio prev Forma vendita  \
# 0                     NaN           NaN
# 1                     NaN           NaN
# 2                     NaN           NaN
# 3                     NaN           NaN
# 4                     NaN           NaN
# ...                   ...           ...
# 6899     somministrazione         misto
# 6900     somministrazione         misto
# 6901     somministrazione         misto
# 6902     somministrazione         misto
# 6903     somministrazione         misto
#
#                                      Settore storico pe  \
# 0     Ristorante, trattoria, osteria;Genere Merceol....
# 1                             Bar gastronomici e simili
# 2                             Bar gastronomici e simili
# 3     BAR CAFFÿý E SIMILI;Ristorante, trattoria, ost...
# 4                             Bar gastronomici e simili
# ...                                                 ...
# 6899                     Wine,birr.,pub enot.,caff.,the
# 6900                     Wine,birr.,pub enot.,caff.,the
# 6901      BAR CAFFÿý E SIMILI;Bar gastronomici e simili
# 6902                     Wine,birr.,pub enot.,caff.,the
# 6903                     Wine,birr.,pub enot.,caff.,the
#
#       Superficie somministrazione
# 0                            83.0
# 1                            26.0
# 2                            58.0
# 3                           101.0
# 4                            51.0
# ...                           ...
# 6899                         59.0
# 6900                         40.0
# 6901                         53.0
# 6902                         43.0
# 6903                         95.0
#
# [6904 rows x 13 columns]

# %%
# Understand the shape of the dataset
ESERCIZI.shape
# Out:
# (6904, 13)

# %%
# Printing the columns
ESERCIZI.columns
# Out:
# Index(['þÿTipo esercizio storico pe', 'Insegna', 'Ubicazione', 'Tipo via',
#        'Descrizione via', 'Civico', 'Codice via', 'ZD', 'Forma commercio',
#        'Forma commercio prev', 'Forma vendita', 'Settore storico pe',
#        'Superficie somministrazione'],
#       dtype='object')

# %%
# Understand the types of data
ESERCIZI.dtypes
# Out:
# þÿTipo esercizio storico pe     object
# Insegna                         object
# Ubicazione                      object
# Tipo via                        object
# Descrizione via                 object
# Civico                          object
# Codice via                       int64
# ZD                               int64
# Forma commercio                 object
# Forma commercio prev            object
# Forma vendita                   object
# Settore storico pe              object
# Superficie somministrazione    float64
# dtype: object

# %%
#Try to understand the different types of exercise's types there are
ESERCIZI['þÿTipo esercizio storico pe'].unique()
# Out:
# array([nan, 'bar caffÿý', "bar-caffe' e simili",
#        'bar gastronomici e simili', 'bar pasticc.gelat.crem.creper.',
#        'birreria', 'cibi cotti', 'cibi cotti preconfezionati',
#        'gelateria', 'genere merceol.autorizz.sanit.', 'mensa', 'osteria',
#        'pizzeria', 'pizzerie e simili', 'prodotti di gastronomia',
#        'ristorante', 'ristorante, trattoria, osteria',
#        'sale da ballo, locali notturni', 'spaccio bevande analcoliche',
#        'tav.calde,self service,fast f.', 'tavola calda', 'tavola fredda',
#        'trattoria', 'wine,birr.,pub enot.,caff.,the'], dtype=object)

# %%
ESERCIZI['Descrizione via'].unique()
# Out:
# array(['NAVIGLIO GRANDE', 'NAVIGLIO PAVESE', 'DI PORTA NUOVA', ...,
#        'PAPA DARIO', 'SIBARI', 'CASTROVILLARI'],
#       shape=(1840,), dtype=object)

# %%
ESERCIZI['Forma commercio'].unique()
# Out:
# array([nan, 'solo somministrazione', 'somministrazione/minuto'],
#       dtype=object)

# %%
ESERCIZI['Forma commercio prev'].unique()
# Out:
# array([nan, 'somministrazione', 'minuto'], dtype=object)

# %%
ESERCIZI['Forma vendita'].unique()
# Out:
# array([nan, 'misto', 'al banco', 'al tavolo', 'self service'],
#       dtype=object)

# %%
ESERCIZI['Settore storico pe'].unique()
# Out:
# array(['Ristorante, trattoria, osteria;Genere Merceol.Autorizz.Sanit.;Ristorante',
#        'Bar gastronomici e simili',
#        'BAR CAFFÿý E SIMILI;Ristorante, trattoria, osteria', ...,
#        "LETT. GIOCHI LECITI + SOCIETA';Genere Merceol.Autorizz.Sanit.;Trattoria;Ristorante, trattoria, osteria",
#        'Disco-piano-americ.bar serali;Trattoria;BAR CAFFÿý E SIMILI;Pizzerie e simili;Ristorante, trattoria, osteria;Pizzeria;Genere Merceol.Autorizz.Sanit.',
#        'Tavola calda;Pizzeria;Ristorante, trattoria, osteria;Trattoria;Genere Merceol.Autorizz.Sanit.'],
#       shape=(3976,), dtype=object)

# %%
# Grouping by 'Codice Via' and counting
via_count = ESERCIZI['Codice via'].value_counts().sort_index()
# Out:
# 74

# %%
# If needed, here group by other columns

# %%
# Look for duplicates
duplicates = ESERCIZI.duplicated()
duplicates.any()
# Out:
# np.True_

# %%
# Duplicates have been found, print them
ESERCIZI[duplicates]
#Only one has been found at the moment
# Out:
#     þÿTipo esercizio storico pe Insegna                  Ubicazione Tipo via  \
# 940                         NaN     NaN  VIA SALASCO N. 29 (z.d. 5)      VIA
#
#     Descrizione via Civico  Codice via  ZD Forma commercio  \
# 940         SALASCO     29        4051   5             NaN
#
#     Forma commercio prev Forma vendita           Settore storico pe  \
# 940                  NaN           NaN  Spaccio bevande analcoliche
#
#      Superficie somministrazione
# 940                          NaN

# %%
# Look for null values
ESERCIZI.isnull()
# Out:
#       þÿTipo esercizio storico pe  Insegna  Ubicazione  Tipo via  \
# 0                            True     True       False     False
# 1                            True     True       False     False
# 2                            True     True       False     False
# 3                            True     True       False     False
# 4                            True     True       False     False
# ...                           ...      ...         ...       ...
# 6899                        False    False       False     False
# 6900                        False    False       False     False
# 6901                        False    False       False     False
# 6902                        False    False       False     False
# 6903                        False    False       False     False
#
#       Descrizione via  Civico  Codice via     ZD  Forma commercio  \
# 0               False   False       False  False             True
# 1               False   False       False  False             True
# 2               False   False       False  False             True
# 3               False   False       False  False             True
# 4               False   False       False  False             True
# ...               ...     ...         ...    ...              ...
# 6899            False   False       False  False            False
# 6900            False   False       False  False            False
# 6901            False   False       False  False            False
# 6902            False   False       False  False            False
# 6903            False   False       False  False            False
#
#       Forma commercio prev  Forma vendita  Settore storico pe  \
# 0                     True           True               False
# 1                     True           True               False
# 2                     True           True               False
# 3                     True           True               False
# 4                     True           True               False
# ...                    ...            ...                 ...
# 6899                 False          False               False
# 6900                 False          False               False
# 6901                 False          False               False
# 6902                 False          False               False
# 6903                 False          False               False
#
#       Superficie somministrazione
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 6899                        False
# 6900                        False
# 6901                        False
# 6902                        False
# 6903                        False
#
# [6904 rows x 13 columns]

# %%
nulls = {}
for col in ESERCIZI.columns:
    nulls[col] = ESERCIZI[col].isnull().sum()
    
print(nulls)
# Out:
# {'þÿTipo esercizio storico pe': np.int64(1353), 'Insegna': np.int64(3410), 'Ubicazione': np.int64(0), 'Tipo via': np.int64(0), 'Descrizione via': np.int64(0), 'Civico': np.int64(156), 'Codice via': np.int64(0), 'ZD': np.int64(0), 'Forma commercio': np.int64(1571), 'Forma commercio prev': np.int64(1397), 'Forma vendita': np.int64(1424), 'Settore storico pe': np.int64(21), 'Superficie somministrazione': np.int64(79)}

# %%
# Number of not null values. Clearly there are some problematic columns, such as 'Insegna'
ESERCIZI.count()
# Out:
# þÿTipo esercizio storico pe    5551
# Insegna                        3494
# Ubicazione                     6904
# Tipo via                       6904
# Descrizione via                6904
# Civico                         6748
# Codice via                     6904
# ZD                             6904
# Forma commercio                5333
# Forma commercio prev           5507
# Forma vendita                  5480
# Settore storico pe             6883
# Superficie somministrazione    6825
# dtype: int64
