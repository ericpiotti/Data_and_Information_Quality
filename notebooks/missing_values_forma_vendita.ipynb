# %%
import pandas as pd
import numpy as np

# %%
MILANO = pd.read_csv('../Dataset/Comune-di-Milano-Pubblici-esercizi(in)-2.csv',sep=';',encoding='utf-8')

# %%
MILANO[["Forma commercio prev", "Forma commercio", "Forma vendita"]]
# Out:
#      Forma commercio prev        Forma commercio Forma vendita
# 0                     NaN                    NaN           NaN
# 1                     NaN                    NaN           NaN
# 2                     NaN                    NaN           NaN
# 3                     NaN                    NaN           NaN
# 4                     NaN                    NaN           NaN
# ...                   ...                    ...           ...
# 6899     somministrazione  solo somministrazione         misto
# 6900     somministrazione  solo somministrazione         misto
# 6901     somministrazione  solo somministrazione         misto
# 6902     somministrazione  solo somministrazione         misto
# 6903     somministrazione  solo somministrazione         misto
#
# [6904 rows x 3 columns]

# %%
MILANO["Forma commercio"].unique()
# Out:
# array([nan, 'solo somministrazione', 'somministrazione/minuto'],
#       dtype=object)

# %%
MILANO["Forma commercio prev"].unique()
# Out:
# array([nan, 'somministrazione', 'minuto'], dtype=object)

# %%
MILANO["Forma vendita"].unique()
# Out:
# array([nan, 'misto', 'al banco', 'al tavolo', 'self service'],
#       dtype=object)

# %%
MILANO[MILANO["Forma commercio"] == "somministrazione/minuto"]
# Out:
#      þÿTipo esercizio storico pe                    Insegna  \
# 1337                         NaN              bar sunflower
# 1358                  bar caffÿý                        NaN
# 1359                  bar caffÿý                        NaN
# 1360                  bar caffÿý                        NaN
# 1361                  bar caffÿý                        NaN
# ...                          ...                        ...
# 6683                   trattoria             free time cafe
# 6731                   trattoria               lo  scarabeo
# 6760                   trattoria              osteria ma.si
# 6811                   trattoria   rist. pizz. la rosa nera
# 6855                   trattoria  trattoria bolognese da m.
#
#                                              Ubicazione Tipo via  \
# 1337  CSO MAGENTA N. 78 ;via verri pietro 008; isola...      CSO
# 1358  CSO BUENOS AIRES N. 2 ; isolato:143; accesso: ...      CSO
# ...
